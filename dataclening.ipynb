# %%
import pandas as pd

# %%
with open("datafortaxifare.csv", "r", errors="ignore") as f:
    for i in range(10):   # print first 10 lines
        print(f.readline())
# Out:
# ,VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,RatecodeID,store_and_fwd_flag,PULocationID,DOLocationID,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount,congestion_surcharge,Airport_fee,airport_fee
#
# 0,2,2023-06-30 23:59:59,2023-07-01 00:47:49,2.0,17.62,2.0,N,132,230,1,70.0,0.0,0.5,0.0,6.55,1.0,82.3,2.5,1.75,
#
# 1,2,2023-06-30 23:59:57,2023-07-01 00:17:36,1.0,3.32,1.0,N,255,198,1,18.4,1.0,0.5,2.5,0.0,1.0,23.4,0.0,0.0,
#
# 2,1,2023-06-30 23:59:55,2023-07-01 00:14:20,1.0,2.8,1.0,N,231,107,1,14.9,3.5,0.5,3.95,0.0,1.0,23.85,2.5,0.0,
#
# 3,2,2023-06-30 23:59:55,2023-07-01 00:05:52,1.0,0.89,1.0,N,237,163,1,7.2,1.0,0.5,2.0,0.0,1.0,14.2,2.5,0.0,
#
# 4,2,2023-06-30 23:59:55,2023-07-01 00:07:08,4.0,1.56,1.0,N,211,90,1,10.0,1.0,0.5,3.0,0.0,1.0,18.0,2.5,0.0,
#
# 5,2,2023-06-30 23:59:54,2023-07-01 00:14:58,1.0,3.85,1.0,N,161,166,1,19.1,1.0,0.5,10.0,0.0,1.0,34.1,2.5,0.0,
#
# ...

# %%
import pandas as pd

# Skip the first column (useless index column)
data = pd.read_csv("datafortaxifare.csv", index_col=0)

# Check first rows
print(data.head())
print(data.info())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[13], line 4
#       1 import pandas as pd
#       3 # Skip the first column (useless index column)
# ----> 4 data = pd.read_csv("datafortaxifare.csv", index_col=0)
#       6 # Check first rows
#       7 print(data.head())
#
# ...
